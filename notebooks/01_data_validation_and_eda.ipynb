# %% [markdown]
# # Retail Sales & Profitability Analysis - Data Validation and EDA
#
# ## Objective
# Understand the structure and quality of the retail transaction data to ensure it is reliable for profitability and performance analysis.
# ## Goals for this notebook:
# - Understanding the structure of the dataset (granularity, columns, and relationships)
# - Identifying data quality issues (missing values, duplicates, invalid or inconsistent records)
# - Performing initial cleaning to prepare a reliable dataset for analysis
#     - Exporting a cleaned dataset for use in exploratory and financial analysis
